# %%
import pandas as pd 
from bs4 import BeautifulSoup
import requests
import time

# %%
def get_content(url):
    start = time.time()
    go = True
    i = 1
    content = []
    while(go):
        response = requests.get(url+str(i))
        if "Sorry no bots match that combination" in response.content.decode():
            go = False
        else:
            content.append(response.content)
        if i % 10 == 0:
            print("Page no. {} downloaded".format(i))
        i += 1 
    num_of_pages = i-1 
    total_time = start - time.time()
    return content, num_of_pages, total_time

# %%
# %time content = get_content("https://botlist.co/bots/filter?category=&platform=&order=date&page=")
# Out:
# Page no. 10 downloaded
# Page no. 20 downloaded
# Page no. 30 downloaded
# Page no. 40 downloaded
# Page no. 50 downloaded
# Page no. 60 downloaded
# Page no. 70 downloaded
# Page no. 80 downloaded
# Page no. 90 downloaded
# Page no. 100 downloaded
# Page no. 110 downloaded
# Page no. 120 downloaded
# Page no. 130 downloaded
# Page no. 140 downloaded
# Page no. 150 downloaded
# Page no. 160 downloaded
# Page no. 170 downloaded
# Page no. 180 downloaded
# Page no. 190 downloaded
# Page no. 200 downloaded
# Page no. 210 downloaded
# Page no. 220 downloaded
# Page no. 230 downloaded
# Page no. 240 downloaded
# Wall time: 3min 15s

# %%
content_df = pd.DataFrame(content)

# %%
content_df.columns = ["html"]

# %%
content_df
# Out:
#                                                   html
# 0    b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 1    b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 2    b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 3    b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 4    b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 5    b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 6    b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 7    b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 8    b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 9    b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 10   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 11   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 12   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 13   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 14   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 15   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 16   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 17   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 18   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 19   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 20   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 21   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 22   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 23   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 24   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 25   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 26   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 27   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 28   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 29   b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# ..                                                 ...
# 218  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 219  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 220  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 221  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 222  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 223  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 224  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 225  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 226  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 227  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 228  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 229  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 230  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 231  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 232  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 233  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 234  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 235  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 236  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 237  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 238  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 239  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 240  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 241  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 242  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 243  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 244  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 245  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 246  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 247  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
#
# [248 rows x 1 columns]

# %%
# page = content_df.html.values[0]

# %%
# soup = BeautifulSoup(page, 'html.parser')

# %%
# x = soup.find_all("div",class_="bot")[0]

# %%
# x.find('a').get("href")

# %%
# x.find_all('a')[-1].get_text()

# %%
# page = content_df.html.values[0]

# %%
def extract_urls_and_names(page):
    lst = []
    soup = BeautifulSoup(page, 'html.parser')
    bots = soup.find_all("div",class_="bot")
    for bot in bots:
        sub_lst = []
        sub_lst.append(bot.find_all('a')[0].get("href"))
        sub_lst.append(bot.find_all('a')[-1].get_text())
        lst.append(sub_lst)
    return lst

# %%
# extract_urls_and_names(page)

# %%
content_df["bot_data"] = content_df["html"].apply(extract_urls_and_names)
# Out:
#                                                 html  \
# 0  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 1  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 2  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 3  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
# 4  b'<!DOCTYPE html>\n<html lang="en">\n<head>\n ...
#
#                                             bot_data
# 0  [[https://botlist.co/bots/3277-music-monkey, M...
# 1  [[https://botlist.co/bots/3265-group-vote, Gro...
# 2  [[https://botlist.co/bots/3253-humbot, Humbot]...
# 3  [[https://botlist.co/bots/3238-me, Me], [https...
# 4  [[https://botlist.co/bots/3227-garyvee-365, Ga...

# %%
def get_names_and_urls(pages):
    lst_total = []
    for page in pages:
        lst_total.append(extract_urls_and_names(page))
    return lst_total

# %%
pages = content_df.html.values
# %time names_urls = get_names_and_urls(pages)
# Out:
# Wall time: 11.2 s

# %%
names_urls = sum(names_urls,[])

# %%
bots_df = pd.DataFrame(names_urls)
bots_df.columns = ["url","name"]

# %%
# bots_df
# Out:
#                                                     url  \
# 0             https://botlist.co/bots/3277-music-monkey
# 1           https://botlist.co/bots/3276-food-scout-bot
# 2               https://botlist.co/bots/3275-yahoo-news
# 3                  https://botlist.co/bots/3274-airwave
# 4                 https://botlist.co/bots/3273-slotobot
# 5                https://botlist.co/bots/3272-kryptobot
# 6              https://botlist.co/bots/3271-allanswered
# 7                    https://botlist.co/bots/3270-moodz
# 8                  https://botlist.co/bots/3269-timebot
# 9                 https://botlist.co/bots/3268-skillbot
# 10        https://botlist.co/bots/3267-trendinggiphybot
# 11          https://botlist.co/bots/3266-openmensarobot
# 12              https://botlist.co/bots/3265-group-vote
# 13                 https://botlist.co/bots/3264-gamepix
# 14                  https://botlist.co/bots/3263-sweepr
# 15               https://botlist.co/bots/3262-botletter
# 16         https://botlist.co/bots/3261-translateid-bot
# 17                     https://botlist.co/bots/3260-exa
# 18                  https://botlist.co/bots/3257-zomboy
# 19                 https://botlist.co/bots/3259-shakira
# 20              https://botlist.co/bots/3258-john-keats
# 21               https://botlist.co/bots/3256-commander
# 22           https://botlist.co/bots/3255-confused-coin
# 23               https://botlist.co/bots/3254-solucoach
# 24                  https://botlist.co/bots/3253-humbot
# 25                https://botlist.co/bots/3252-bot-cafe
# 26           https://botlist.co/bots/3251-codesidestory
# 27                  https://botlist.co/bots/3250-qaqash
# 28    https://botlist.co/bots/3249-the-affiliate-jou...
# 29       https://botlist.co/bots/3248-t-the-t-shirt-bot
# ...                                                 ...
# 2936                  https://botlist.co/bots/36-reside
# 2937           https://botlist.co/bots/33-clockwork-sms
# 2938             https://botlist.co/bots/32-gone-by-sms
# 2939              https://botlist.co/bots/31-text-a-pro
# 2940                   https://botlist.co/bots/27-sonar
# 2941            https://botlist.co/bots/26-stefans-head
# 2942                   https://botlist.co/bots/25-riley
# 2943              https://botlist.co/bots/24-awesome-pa
# 2944                  https://botlist.co/bots/21-unload
# 2945                   https://botlist.co/bots/20-penny
# 2946                   https://botlist.co/bots/18-digit
# 2947                  https://botlist.co/bots/16-lookup
# 2948      https://botlist.co/bots/15-dispatch-messenger
# 2949             https://botlist.co/bots/13-assistantto
# 2950                     https://botlist.co/bots/12-xai
# 2951                   https://botlist.co/bots/11-clara
# 2952              https://botlist.co/bots/10-julie-desk
# 2953                    https://botlist.co/bots/9-carla
# 2954                     https://botlist.co/bots/6-cloe
# 2955                 https://botlist.co/bots/5-gobutler
# 2956                  https://botlist.co/bots/123-figma
# 2957                https://botlist.co/bots/346-workbot
# 2958                  https://botlist.co/bots/23-taylor
# 2959                   https://botlist.co/bots/287-uber
# 2960                https://botlist.co/bots/333-service
# 2961                    https://botlist.co/bots/4-magic
# 2962                 https://botlist.co/bots/3-operator
# 2963                   https://botlist.co/bots/1-assist
# 2964                        https://botlist.co/bots/2-m
# 2965                 https://botlist.co/bots/614-hudson
#
#                            name
# 0                  Music Monkey
# 1                Food Scout Bot
# 2                    Yahoo News
# 3                       AirWave
# 4                      Slotobot
# 5                     Kryptobot
# 6                   AllAnswered
# 7                         Moodz
# 8                       TimeBot
# 9                      SkillBot
# 10             TrendingGiphyBot
# 11               OpenMensaRobot
# 12                   Group-Vote
# 13                      GamePix
# 14                       Sweepr
# 15                    Botletter
# 16              TranslateID_Bot
# 17                          Exa
# 18                       Zomboy
# 19                      Shakira
# 20                   John Keats
# 21                    Commander
# 22                Confused Coin
# 23                    SoluCoach
# 24                       Humbot
# 25                     Bot Cafe
# 26                CodeSideStory
# 27                       QAQASH
# 28    The Affiliate Journal Bot
# 29          T - the t-shirt bot
# ...                         ...
# 2936                     Reside
# 2937              Clockwork SMS
# 2938                Gone by SMS
# 2939                 Text-a-Pro
# 2940                      Sonar
# 2941              Stefan's Head
# 2942                      Riley
# 2943                 Awesome PA
# 2944                     Unload
# 2945                      Penny
# 2946                      Digit
# 2947                     Lookup
# 2948         Dispatch Messenger
# 2949               Assistant.to
# 2950                       X.ai
# 2951                      Clara
# 2952                 Julie Desk
# 2953                      Carla
# 2954                       Cloe
# 2955                   GoButler
# 2956                      Figma
# 2957                    Workbot
# 2958                     Taylor
# 2959                       Uber
# 2960                    Service
# 2961                      Magic
# 2962                   Operator
# 2963                     Assist
# 2964                          M
# 2965                     Hudson
#
# [2966 rows x 2 columns]

# %%
def save_data(path,df):
    df.to_json(path)
    print("Output file saved to: {}".format(path))

# %%
save_data("data/bots.json",bots_df)
# Out:
# Output file saved to: data/bots.json

# %%
save_data("data/raw_pages.json",content_df)
# Out:
# Output file saved to: data/raw_pages.json
